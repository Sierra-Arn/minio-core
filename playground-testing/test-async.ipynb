# %% [markdown]
# # **Setup Environment**

# %%
# Change directory to the project root so that relative paths in .env
# (e.g., MinIO storage path) resolve correctly
# %cd ../

# %%
import sys
sys.path.append('.')

from pydantic import ValidationError
from botocore.exceptions import ClientError
import aiohttp
from app import minio_config
from app.async_storage.service import AsyncStorageService
from app.schemas import UploadFileRequest

# %%
# Change directory to 'assets/' so that files can be referenced directly
# (e.g., 'Kant_the-critique-of-pure-reason.pdf' instead of 'assets/Kant_the-critique-of-pure-reason.pdf')
# %cd playground-testing/assets/

# %% [markdown]
# # **Test**
#
# ## **I. Test `upload_temp()` and `upload_permanent()`**

# %%
async def test_upload(storage_key: str, file_path: str) -> bool:

    request = UploadFileRequest(storage_key=storage_key, file_path=file_path)

    for method, label in [
        (AsyncStorageService.upload_temp, "temp"),
        (AsyncStorageService.upload_permanent, "permanent"),
    ]:
        try:
            await method(request)
            print(f"[{label}] File '{storage_key}' uploaded successfully.")

        except ValidationError as e:
            print(f"[{label}] Validation error: {e}")
            return False

        except FileNotFoundError as e:
            print(f"[{label}] File not found: {e}")
            return False

        except ClientError as e:
            error_code = e.response['Error']['Code']
            print(f"[{label}] S3 ClientError ({error_code}): {e}")
            return False

        except Exception as e:
            print(f"[{label}] Unexpected error: {e}")
            return False

    return True

# %%
await test_upload(storage_key="kant-book", file_path="Kant_the-critique-of-pure-reason.pdf")

# %%
# Attempting to upload a non-existent file
await test_upload(storage_key="tarski-logic-book", file_path="Tarski1948")

# %% [markdown]
# ## **II. Test `download()`**

# %%
async def test_download(storage_key: str, file_path: str) -> bool:
    try:
        await AsyncStorageService.download(storage_key=storage_key, file_path=file_path)
        print(f"File '{storage_key}' downloaded successfully to '{file_path}'.")
        return True

    except ClientError as e:
        error_code = e.response['Error']['Code']
        print(f"S3 ClientError ({error_code}): {e}")
        return False

    except Exception as e:
        print(f"Unexpected error: {e}")
        return False

# %%
await test_download(storage_key=f"{minio_config.permanent_prefix}kant-book", file_path="export.pdf")

# %%
# Attempting to download a non-existent file
await test_download(storage_key="kant-book", file_path="export.pdf")

# %% [markdown]
# ## **III. Test `get_metadata()`**

# %%
async def test_get_metadata(storage_key: str) -> bool:
    try:
        metadata = await AsyncStorageService.get_metadata(storage_key=storage_key)
        print(f"Metadata retrieved for '{storage_key}':")
        print(metadata)
        return True

    except ClientError as e:
        error_code = e.response['Error']['Code']
        print(f"S3 ClientError ({error_code}): {e}")
        return False

    except Exception as e:
        print(f"Unexpected error: {e}")
        return False

# %%
await test_get_metadata(storage_key=f"{minio_config.permanent_prefix}kant-book")

# %%
# Attempting to get metadata for a non-existent file
await test_get_metadata(storage_key="do-not-exist")

# %% [markdown]
# ## **IV. Test `delete()`**

# %%
async def test_delete(storage_key: str) -> bool:
    try:
        await AsyncStorageService.delete(storage_key=storage_key)
        print(f"File '{storage_key}' deleted (or did not exist).")
        return True

    except ClientError as e:
        error_code = e.response['Error']['Code']
        print(f"S3 ClientError ({error_code}): {e}")
        return False

    except Exception as e:
        print(f"Unexpected error: {e}")
        return False

# %%
await test_delete(storage_key=f"{minio_config.permanent_prefix}kant-book")

# %%
# Attempting to delete a non-existent file
await test_delete(storage_key="kant-book")

# %% [markdown]
# ## **V. Test `generate_presigned_put_url_temp()` and `generate_presigned_put_url_permanent()`**

# %%
async def test_generate_presigned_put_url(storage_key: str, content_type: str, expires: int = 3600) -> tuple[str, str] | None:

    urls = {}

    for method, label in [
        (AsyncStorageService.generate_presigned_put_url_temp, "temp"),
        (AsyncStorageService.generate_presigned_put_url_permanent, "permanent"),
    ]:
        try:
            url = await method(storage_key=storage_key, content_type=content_type, expires=expires)
            print(f"[{label}] Presigned PUT URL generated for '{storage_key}' (expires in {expires}s).")
            urls[label] = url

        except ClientError as e:
            error_code = e.response['Error']['Code']
            print(f"[{label}] S3 ClientError ({error_code}): {e}")
            return None

        except Exception as e:
            print(f"[{label}] Unexpected error: {e}")
            return None

    return urls["temp"], urls["permanent"]

# %%
urls = await test_generate_presigned_put_url(storage_key="new-kant", content_type="application/pdf")

# %% [markdown]
# ## **VI. Test uploading via presigned PUT URL**

# %%
async def test_upload_via_presigned_put_url(
    temp_url: str,
    permanent_url: str,
    file_path: str,
    content_type: str,
) -> bool:

    for url, label in [
        (temp_url, "temp"),
        (permanent_url, "permanent"),
    ]:
        try:
            async with aiohttp.ClientSession() as session:
                with open(file_path, "rb") as f:
                    async with session.put(url, data=f, headers={"Content-Type": content_type}) as response:
                        if response.status == 200:
                            print(f"[{label}] File '{file_path}' successfully uploaded via presigned URL.")
                        else:
                            print(f"[{label}] Upload failed. HTTP {response.status}: {await response.text()}")
                            return False

        except Exception as e:
            print(f"[{label}] Unexpected error: {e}")
            return False

    return True

# %%
await test_upload_via_presigned_put_url(
    temp_url=urls[0],
    permanent_url=urls[1],
    file_path="Kant_the-critique-of-pure-reason.pdf",
    content_type="application/pdf"
)

# %%
# Attempting to upload with a mismatched Content-Type
await test_upload_via_presigned_put_url(
    temp_url=urls[0],
    permanent_url=urls[1],
    file_path="Kant_the-critique-of-pure-reason.pdf",
    content_type="image/jpeg"
)

# %% [markdown]
# ## **VII. Test `generate_presigned_get_url()`**

# %%
async def test_generate_presigned_get_url(storage_key: str, expires: int = 3600) -> str | None:

    try:
        url = await AsyncStorageService.generate_presigned_get_url(storage_key=storage_key, expires=expires)
        print(f"Presigned GET URL generated for '{storage_key}' (expires in {expires}s).")
        return url

    except ClientError as e:
        error_code = e.response['Error']['Code']
        print(f"S3 ClientError ({error_code}): {e}")
        return None

    except Exception as e:
        print(f"Unexpected error: {e}")
        return None

# %%
url = await test_generate_presigned_get_url(storage_key=f"{minio_config.permanent_prefix}new-kant")

# %%
# Attempting to generate presigned GET URL for a non-existent file
await test_generate_presigned_get_url(storage_key="wrong-name")

# %% [markdown]
# ## **VIII. Test downloading via presigned GET URL**

# %%
async def test_download_via_presigned_get_url(presigned_url: str, save_path: str) -> bool:

    try:
        async with aiohttp.ClientSession() as session:
            async with session.get(presigned_url, timeout=aiohttp.ClientTimeout(total=30)) as response:
                if response.status == 200:
                    with open(save_path, "wb") as f:
                        async for chunk in response.content.iter_chunked(8192):
                            if chunk:
                                f.write(chunk)
                    print(f"File successfully downloaded and saved to '{save_path}'.")
                    return True
                else:
                    print(f"Download failed. HTTP {response.status}: {await response.text()}")
                    return False

    except Exception as e:
        print(f"Unexpected error: {e}")
        return False

# %%
await test_download_via_presigned_get_url(presigned_url=url, save_path="export.pdf")

# %%
# Attempting to download from a wrong URL
await test_download_via_presigned_get_url(presigned_url="https://non-existing-url", save_path="export.pdf")
